# %%
# dependencies
import requests
import pandas as pd

# %%
data_file = "Public_School_Locations_201718.csv"

# %%
school_data = pd.read_csv(data_file)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
school_data.head()
# Out:
#            X          Y  OBJECTID       NCESSCH  \
# 0 -88.085445  30.628477      1001  1.023700e+10
# 1 -88.120325  30.696878      1002  1.023700e+10
# 2 -88.098197  30.744804      1003  1.023700e+10
# 3 -88.143275  30.726547      1004  1.023700e+10
# 4 -88.290432  30.786322      1005  1.023700e+10
#
#                                  NAME  OPSTFIPS               STREET  \
# 0               Pillans Middle School         1     2051 Military Rd
# 1  Phillips Preparatory Middle School         1    3255 Old Shell Rd
# 2        WD Robbins Elementary School         1       2416 W Main St
# 3  CL Scarborough Model Middle School         1     1800 Phillips Ln
# 4                Semmes Middle School         1  4566 Ed George Road
#
#        CITY STATE    ZIP  ...      NMCBSA  CBSATYPE  CSA  \
# 0    Mobile    AL  36605  ...  Mobile, AL         1  380
# 1    Mobile    AL  36607  ...  Mobile, AL         1  380
# 2  Prichard    AL  36610  ...  Mobile, AL         1  380
# ...

# %%
# checking if there is the school data of NC
unique_state = school_data["STATE"].unique()
unique_state
# Out:
# array(['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'MD', 'FL',
#        'GA', 'HI', 'ID', 'OR', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME',
#        'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM',
#        'NY', 'NC', 'ND', 'OH', 'OK', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
#        'UT', 'VA', 'VT', 'WA', 'WV', 'WI', 'WY', 'AS', 'GU', 'PR', 'VI'],
#       dtype=object)

# %%
# filtering the data where state = NC
only_nc =  school_data.loc[school_data["STATE"] == "NC", :]
only_nc
# Out:
#                 X          Y  OBJECTID       NCESSCH  \
# 64000  -79.318984  35.946626     65001  3.700130e+11
# 64001  -80.737724  35.411577     65002  3.700130e+11
# 64002  -80.859596  35.501811     65003  3.700140e+11
# 64003  -80.728853  35.072893     65004  3.700140e+11
# 64004  -81.614495  36.227027     65005  3.700140e+11
# 64005  -78.893484  36.046867     65006  3.700140e+11
# 64006  -78.772224  34.404183     65007  3.700140e+11
# 64007  -77.891873  34.238797     65008  3.700140e+11
# 64008  -80.767036  35.250648     65009  3.700140e+11
# 64009  -80.751048  35.155059     65010  3.700140e+11
# 64010  -78.290989  35.535995     65011  3.700140e+11
# 64011  -80.907008  35.577316     65012  3.700150e+11
# 64012  -78.979305  36.392624     65013  3.700180e+11
# 64013  -80.106440  35.105382     65014  3.700180e+11
# 64014  -80.056250  34.942693     65015  3.700180e+11
# 64015  -80.007348  34.879733     65016  3.700180e+11
# 64016  -79.988960  34.963149     65017  3.700180e+11
# ...

# %%
only_nc.count()
# Out:
# X             2707
# Y             2707
# OBJECTID      2707
# NCESSCH       2707
# NAME          2707
# OPSTFIPS      2707
# STREET        2707
# CITY          2707
# STATE         2707
# ZIP           2707
# STFIP         2707
# CNTY          2707
# NMCNTY        2707
# LOCALE        2707
# LAT           2707
# LON           2707
# CBSA          2707
# NMCBSA        2707
# CBSATYPE      2707
# CSA           2707
# NMCSA         2707
# NECTA         2707
# NMNECTA       2707
# CD            2707
# SLDL          2707
# SLDU          2707
# SCHOOLYEAR    2707
# dtype: int64

# %%
#dropping the unwanted columns
#school_data.drop('', axis=indexnum)
